# %%
# home work 1 for data analysis course
# System Admin:
# !pip install radon
# !pip install neuronunit
# Out:
# Collecting radon
#   Downloading radon-2.2.0-py2.py3-none-any.whl (46kB)
#     100% |################################| 51kB 1.0MB/s ta 0:00:01
# Collecting flake8-polyfill (from radon)
#   Downloading flake8_polyfill-1.0.2-py2.py3-none-any.whl
# Collecting mando<0.7,>=0.6 (from radon)
#   Downloading mando-0.6.4-py2.py3-none-any.whl
# Requirement already satisfied: colorama<0.4,>=0.3 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from radon)
# Collecting flake8 (from flake8-polyfill->radon)
#   Downloading flake8-3.5.0-py2.py3-none-any.whl (69kB)
#     100% |################################| 71kB 3.8MB/s ta 0:00:01
# Requirement already satisfied: six in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from mando<0.7,>=0.6->radon)
# Requirement already satisfied: mccabe<0.7.0,>=0.6.0 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from flake8->flake8-polyfill->radon)
# Requirement already satisfied: pycodestyle<2.4.0,>=2.0.0 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from flake8->flake8-polyfill->radon)
# Requirement already satisfied: pyflakes<1.7.0,>=1.5.0 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from flake8->flake8-polyfill->radon)
# Installing collected packages: flake8, flake8-polyfill, mando, radon
# Successfully installed flake8-3.5.0 flake8-polyfill-1.0.2 mando-0.6.4 radon-2.2.0
# Collecting neuronunit
#   Downloading neuronunit-0.1.8.2.tar.gz
# Collecting neo (from neuronunit)
#   Downloading neo-0.5.2.tar.gz (1.4MB)
#     100% |################################| 1.4MB 756kB/s eta 0:00:01
# Collecting elephant (from neuronunit)
#   Downloading elephant-0.4.1.tar.gz (227kB)
#     100% |################################| 235kB 4.1MB/s eta 0:00:01
# Collecting sciunit>=0.1.5.2 (from neuronunit)
#   Downloading sciunit-0.1.5.7.tar.gz
# Requirement already satisfied: numpy>=1.7.1 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from neo->neuronunit)
# Collecting quantities>=0.9.0 (from neo->neuronunit)
#   Downloading quantities-0.12.1.tar.gz (81kB)
#     100% |################################| 81kB 7.3MB/s eta 0:00:01
# Requirement already satisfied: scipy>=0.14.0 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from elephant->neuronunit)
# Requirement already satisfied: six>=1.10.0 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from elephant->neuronunit)
# Collecting cypy>=0.2 (from sciunit>=0.1.5.2->neuronunit)
#   Downloading cypy-0.2.0.tar.gz
# Requirement already satisfied: pandas>=0.18 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from sciunit>=0.1.5.2->neuronunit)
# Requirement already satisfied: ipython>=5.1 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from sciunit>=0.1.5.2->neuronunit)
# Collecting bs4 (from sciunit>=0.1.5.2->neuronunit)
#   Downloading bs4-0.0.1.tar.gz
# Requirement already satisfied: lxml in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from sciunit>=0.1.5.2->neuronunit)
# Requirement already satisfied: nbconvert in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from sciunit>=0.1.5.2->neuronunit)
# Requirement already satisfied: ipykernel in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from sciunit>=0.1.5.2->neuronunit)
# Requirement already satisfied: nbformat in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from sciunit>=0.1.5.2->neuronunit)
# Requirement already satisfied: python-dateutil>=2 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from pandas>=0.18->sciunit>=0.1.5.2->neuronunit)
# Requirement already satisfied: pytz>=2011k in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from pandas>=0.18->sciunit>=0.1.5.2->neuronunit)
# Requirement already satisfied: setuptools>=18.5 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from ipython>=5.1->sciunit>=0.1.5.2->neuronunit)
# Requirement already satisfied: jedi>=0.10 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from ipython>=5.1->sciunit>=0.1.5.2->neuronunit)
# Requirement already satisfied: decorator in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from ipython>=5.1->sciunit>=0.1.5.2->neuronunit)
# Requirement already satisfied: pickleshare in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from ipython>=5.1->sciunit>=0.1.5.2->neuronunit)
# Requirement already satisfied: simplegeneric>0.8 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from ipython>=5.1->sciunit>=0.1.5.2->neuronunit)
# Requirement already satisfied: traitlets>=4.2 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from ipython>=5.1->sciunit>=0.1.5.2->neuronunit)
# Requirement already satisfied: prompt_toolkit<2.0.0,>=1.0.4 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from ipython>=5.1->sciunit>=0.1.5.2->neuronunit)
# Requirement already satisfied: pygments in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from ipython>=5.1->sciunit>=0.1.5.2->neuronunit)
# Requirement already satisfied: pexpect in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from ipython>=5.1->sciunit>=0.1.5.2->neuronunit)
# Requirement already satisfied: beautifulsoup4 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from bs4->sciunit>=0.1.5.2->neuronunit)
# Requirement already satisfied: mistune>=0.7.4 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from nbconvert->sciunit>=0.1.5.2->neuronunit)
# Requirement already satisfied: jinja2 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from nbconvert->sciunit>=0.1.5.2->neuronunit)
# Requirement already satisfied: jupyter_core in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from nbconvert->sciunit>=0.1.5.2->neuronunit)
# Requirement already satisfied: entrypoints>=0.2.2 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from nbconvert->sciunit>=0.1.5.2->neuronunit)
# Requirement already satisfied: bleach in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from nbconvert->sciunit>=0.1.5.2->neuronunit)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from nbconvert->sciunit>=0.1.5.2->neuronunit)
# Requirement already satisfied: testpath in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from nbconvert->sciunit>=0.1.5.2->neuronunit)
# Requirement already satisfied: jupyter_client in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from ipykernel->sciunit>=0.1.5.2->neuronunit)
# Requirement already satisfied: tornado>=4.0 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from ipykernel->sciunit>=0.1.5.2->neuronunit)
# Requirement already satisfied: ipython_genutils in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from nbformat->sciunit>=0.1.5.2->neuronunit)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from nbformat->sciunit>=0.1.5.2->neuronunit)
# Requirement already satisfied: wcwidth in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from prompt_toolkit<2.0.0,>=1.0.4->ipython>=5.1->sciunit>=0.1.5.2->neuronunit)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from jinja2->nbconvert->sciunit>=0.1.5.2->neuronunit)
# Requirement already satisfied: html5lib>=0.99999999 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from bleach->nbconvert->sciunit>=0.1.5.2->neuronunit)
# Requirement already satisfied: pyzmq>=13 in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from jupyter_client->ipykernel->sciunit>=0.1.5.2->neuronunit)
# Requirement already satisfied: webencodings in /home/nbuser/anaconda3_501/lib/python3.6/site-packages (from html5lib>=0.99999999->bleach->nbconvert->sciunit>=0.1.5.2->neuronunit)
# Building wheels for collected packages: neuronunit, neo, elephant, sciunit, quantities, cypy, bs4
#   Running setup.py bdist_wheel for neuronunit ... done
#   Stored in directory: /home/nbuser/.cache/pip/wheels/f8/e3/31/ff8f0c6797e342924436972aa5a1fa1483238e911309eddfc7
#   Running setup.py bdist_wheel for neo ... done
#   Stored in directory: /home/nbuser/.cache/pip/wheels/0c/d1/7b/0dd873da92881840dda3bc6c17f1d524c1c91d61eecd7fc31c
#   Running setup.py bdist_wheel for elephant ... done
#   Stored in directory: /home/nbuser/.cache/pip/wheels/77/ac/2a/bdf21cb26c78876aee7e72c571efe61ca7632bad73088c3138
#   Running setup.py bdist_wheel for sciunit ... done
#   Stored in directory: /home/nbuser/.cache/pip/wheels/39/73/0d/df8f4ff96c6c15909f648a4f2b83d89ef7693ce15db0de39d8
#   Running setup.py bdist_wheel for quantities ... done
#   Stored in directory: /home/nbuser/.cache/pip/wheels/88/ff/0e/34ded60ca6cddc546c9d824f41950fd972e6fdb5f5352acb80
#   Running setup.py bdist_wheel for cypy ... done
#   Stored in directory: /home/nbuser/.cache/pip/wheels/7a/4e/c4/90b11d241a3857f858da164f79a2f20dadff2a1d09b905ec3e
#   Running setup.py bdist_wheel for bs4 ... done
#   Stored in directory: /home/nbuser/.cache/pip/wheels/84/67/d4/9e09d9d5adede2ee1c7b7e8775ba3fbb04d07c4f946f0e4f11
# Successfully built neuronunit neo elephant sciunit quantities cypy bs4
# Installing collected packages: quantities, neo, elephant, cypy, bs4, sciunit, neuronunit
# Successfully installed bs4-0.0.1 cypy-0.2.0 elephant-0.4.1 neo-0.5.2 neuronunit-0.1.8.2 quantities-0.12.1 sciunit-0.1.5.7

# %%
def ccomplexity_rater(other_function):
    '''
    This function calculates the radian cyclomatic complexity of other functions.
    Radian complexity is used as a proxy for cognitive complexity, ie how hard is a code block to understand.
    Inputs: Other Python functions.
    Outputs: A positive integer value that is located in the interval 1-41. The scalar is used in conjunction
    with a printed legend.    
    
    The program first uses introspection to convert other_function to a string representation of the
    source code that the function was originally expressed in. 
    Subsequently another module radon that calculates cognitive complexity is called. 
    Dependencies: If the radon module is not installed consider executing ```pip install radon```
    From:   http://radon.readthedocs.io/en/latest/api.html
    https://www.guru99.com/cyclomatic-complexity.html

    '''
    import pandas as pd
    import inspect, radon, pprint
    from radon.complexity import cc_rank, cc_visit
    f_source_code = "".join(inspect.getsourcelines(other_function)[0])
    results = radon.complexity.cc_visit(f_source_code)
    ranking = radon.complexity.sorted_results(results)
    pp = pprint.PrettyPrinter(indent=4)
    ranking_guide = '''  
    1 - 5 A (low risk - simple block) 
    6 - 10 B (low risk - well structured and stable block) 
    11 - 20 C (moderate risk - slightly complex block) 
    21 - 30 D (more than moderate risk - more complex block) 
    31 - 40 E (high risk - complex block, alarming) 
    41+ F (very high risk - error-prone, unstable block) 
    '''
    pp.pprint(ranking_guide)
    actual_value = ranking[0][-1]
    pp.pprint('cognitive complexity of function {0} is: {1}'.format(other_function,actual_value))
    #df = pd.DataFrame(['cognitive complexity of function: '+str(other_function),actual_value])

    if actual_value > 10:
        pp.pprint('Consider rewriting your code it might be hard for you and others to understand, and therefore maintain')
    else:
        pp.pprint('Good work keep writing modular, readable, and simple code.')
        
    return actual_value

# %% [markdown]
# ## Example Use
# Compute the cognitive complexity of the complexity_rater function itself.
# ## Compute the complexity on a list of functions.
# TODO improve the output by using pandas data frames.

# %%
 

ccomplexity_rater(ccomplexity_rater)
from neuronunit import sciunit, capabilities
actual_values = list(map(ccomplexity_rater,[capabilities.spikes2amplitudes, sciunit.Test,sciunit.TestSuite,sciunit.Model]))
# Out:
# ('  \n'
#  '    1 - 5 A (low risk - simple block) \n'
#  '    6 - 10 B (low risk - well structured and stable block) \n'
#  '    11 - 20 C (moderate risk - slightly complex block) \n'
#  '    21 - 30 D (more than moderate risk - more complex block) \n'
#  '    31 - 40 E (high risk - complex block, alarming) \n'
#  '    41+ F (very high risk - error-prone, unstable block) \n'
#  '    ')
# ('cognitive complexity of function <function ccomplexity_rater at '
#  '0x7f100750ad08> is: 2')
# 'Good work keep writing modular, readable, and simple code.'
# ('  \n'
#  '    1 - 5 A (low risk - simple block) \n'
#  '    6 - 10 B (low risk - well structured and stable block) \n'
#  '    11 - 20 C (moderate risk - slightly complex block) \n'
#  '    21 - 30 D (more than moderate risk - more complex block) \n'
#  '    31 - 40 E (high risk - complex block, alarming) \n'
#  '    41+ F (very high risk - error-prone, unstable block) \n'
#  '    ')
# ('cognitive complexity of function <function spikes2amplitudes at '
#  '0x7f10007e09d8> is: 2')
# 'Good work keep writing modular, readable, and simple code.'
# ('  \n'
#  '    1 - 5 A (low risk - simple block) \n'
#  '    6 - 10 B (low risk - well structured and stable block) \n'
#  '    11 - 20 C (moderate risk - slightly complex block) \n'
#  '    21 - 30 D (more than moderate risk - more complex block) \n'
#  '    31 - 40 E (high risk - complex block, alarming) \n'
#  '    41+ F (very high risk - error-prone, unstable block) \n'
#  '    ')
# "cognitive complexity of function <class 'sciunit.Test'> is: 7"
# 'Good work keep writing modular, readable, and simple code.'
# ('  \n'
#  '    1 - 5 A (low risk - simple block) \n'
#  '    6 - 10 B (low risk - well structured and stable block) \n'
#  '    11 - 20 C (moderate risk - slightly complex block) \n'
#  '    21 - 30 D (more than moderate risk - more complex block) \n'
#  '    31 - 40 E (high risk - complex block, alarming) \n'
#  '    41+ F (very high risk - error-prone, unstable block) \n'
#  '    ')
# "cognitive complexity of function <class 'sciunit.TestSuite'> is: 10"
# 'Good work keep writing modular, readable, and simple code.'
# ('  \n'
#  '    1 - 5 A (low risk - simple block) \n'
#  '    6 - 10 B (low risk - well structured and stable block) \n'
#  '    11 - 20 C (moderate risk - slightly complex block) \n'
#  '    21 - 30 D (more than moderate risk - more complex block) \n'
#  '    31 - 40 E (high risk - complex block, alarming) \n'
#  '    41+ F (very high risk - error-prone, unstable block) \n'
#  '    ')
# "cognitive complexity of function <class 'sciunit.Model'> is: 4"
# 'Good work keep writing modular, readable, and simple code.'
